# %% [markdown]
# ### Task 1 - Display the result using a bar graph

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("DS1_C4_S5_Employee_Data_Practice.xlsx")

# %%
df
# Out:
#     Employee_Code   Gender Department  Annual Salary ($)  Age  Work_Experience
# 0             1010    Male        IT               27000   22                0
# 1             1011  Female        IT               48000   27                4
# 2             1012    Male      Sales              75000   31                7
# 3             1013    Male      Sales              61000   29                6
# 4             1014  Female    Finance              45000   27                4
# ..             ...     ...        ...                ...  ...              ...
# 65            1074  Female         HR              82500   43               13
# 66            1075    Male      Sales              53500   28                5
# 67            1076  Female         HR              57000   29                6
# 68            1077    Male      Sales              66500   33                7
# 69            1078    Male    Finance              92000   45               19
#
# [70 rows x 6 columns]

# %%
bar = df.groupby("Department")["Annual Salary ($)"].sum()

# %%
pd.DataFrame(bar)
# Out:
#             Annual Salary ($)
# Department
# Finance                790000
# HR                     987000
# IT                    1282900
# Sales                 1089000

# %%
bar.reset_index()
# Out:
#   Department  Annual Salary ($)
# 0    Finance             790000
# 1         HR             987000
# 2        IT             1282900
# 3      Sales            1089000

# %%
bar.plot(kind ="bar")
plt.title('Department-wise Annual Salary')
plt.xlabel('Department')
plt.ylabel('Annual Salary ($)')
plt.show()

# %% [markdown]
# Interpretation - Here i have displayed the sum of salary for each department

# %% [markdown]
# ### Task 2

# %%
gen = df.groupby(by=['Department','Gender'])["Gender"].count()

# %%
pd.DataFrame(gen)
# Out:
#                    Gender
# Department Gender
# Finance    Female       2
#            Male        11
# HR         Female      11
#            Male         4
# IT         Female      10
#            Male        12
# Sales      Female       4
#            Male        16

# %%
gen.plot(kind="bar")
plt.title("Department wise gender")
plt.xlabel="Department"
plt.ylabel="Gender"
plt.show()

# %% [markdown]
# Interpretation - Here i have displayed the Gender wise calculation for each department

# %% [markdown]
# ### Task 3

# %%
df["Department"].unique()
# Out:
# array(['IT ', 'Sales', 'Finance', 'HR'], dtype=object)

# %%
a = df[(df["Work_Experience"]== 0) & (df["Department"]=="IT ")]

# %%
a
# Out:
#     Employee_Code   Gender Department  Annual Salary ($)  Age  Work_Experience
# 0             1010    Male        IT               27000   22                0
# 7             1017    Male        IT               28000   23                0
# 12            1022    Male        IT               29000   22                0
# 46            1055    Male        IT               27500   22                0
# 47            1056  Female        IT               29000   23                0

# %%
IT_avg = a["Annual Salary ($)"].mean()
IT_avg
# Out:
# 28100.0

# %% [markdown]
# Interpretation - The company offer the salary of 28100 for the new employees with 0 Experience in the IT Department

# %% [markdown]
# ### Task 4

# %%
b = df.groupby(by=["Department"])["Annual Salary ($)"].sum()

# %%
pd.DataFrame(b)
# Out:
#             Annual Salary ($)
# Department
# Finance                790000
# HR                     987000
# IT                    1282900
# Sales                 1089000

# %%
b.plot(kind= "pie")
plt.pie(b,autopct='%.2f%%')
plt.title("Sum of annual salary in each department")

plt.show()

# %% [markdown]
# Interpretation - Here i have displayed the ratio of sum salaries of all employees in each department by using pie chart

# %% [markdown]
# ### Task 5

# %%
df.sort_values("Age",ascending=False)
# Out:
#     Employee_Code   Gender Department  Annual Salary ($)  Age  Work_Experience
# 64            1073    Male        IT              170000   50               24
# 29            1039  Female         HR             140000   49               20
# 58            1067  Female        IT               90000   47               17
# 57            1066  Female        IT               88000   46               16
# 69            1078    Male    Finance              92000   45               19
# ..             ...     ...        ...                ...  ...              ...
# 46            1055    Male        IT               27500   22                0
# 38            1047  Female      Sales              28000   22                0
# 17            1027  Female         HR              28000   22                0
# 12            1022    Male        IT               29000   22                0
# 0             1010    Male        IT               27000   22                0
#
# [70 rows x 6 columns]

# %%
plt.hist(df["Age"],bins=5)
plt.title("Employee count by age group")
plt.xlabel= 'Age group'
plt.ylabel= 'No of employees'

# %% [markdown]
# Interpretation - Here i have displayed the distribution of employee count by age group

# %% [markdown]
# ### Task 6

# %%
a = df.rename(columns={"Annual Salary ($)":"Annual_salary"})
a
# Out:
#     Employee_Code   Gender Department  Annual_salary  Age  Work_Experience
# 0             1010    Male        IT           27000   22                0
# 1             1011  Female        IT           48000   27                4
# 2             1012    Male      Sales          75000   31                7
# 3             1013    Male      Sales          61000   29                6
# 4             1014  Female    Finance          45000   27                4
# ..             ...     ...        ...            ...  ...              ...
# 65            1074  Female         HR          82500   43               13
# 66            1075    Male      Sales          53500   28                5
# 67            1076  Female         HR          57000   29                6
# 68            1077    Male      Sales          66500   33                7
# 69            1078    Male    Finance          92000   45               19
#
# [70 rows x 6 columns]

# %%
plt.scatter(a.Annual_salary , a.Work_Experience)
plt.title("Salary trend based on Experience")
plt.xlabel = "salary"
plt.ylabel = "Experience"
plt.show()

# %% [markdown]
# Interpretation -  Here i have displayed the salary trend based on work experience by using scatter plot

# %% [markdown]
# ### Task 7

# %%
a = df[(df["Department"]=="IT ")]

# %%
a
# Out:
#     Employee_Code   Gender Department  Annual Salary ($)  Age  Work_Experience
# 0             1010    Male        IT               27000   22                0
# 1             1011  Female        IT               48000   27                4
# 7             1017    Male        IT               28000   23                0
# 8             1018  Female        IT               48000   27                4
# 11            1021  Female        IT               45000   27                4
# 12            1022    Male        IT               29000   22                0
# 15            1025    Male        IT               78000   33                8
# 19            1029    Male        IT               42000   27                4
# 24            1034    Male        IT               52000   28                5
# 25            1035    Male        IT               36000   26                2
# 26            1036    Male        IT               48000   27                4
# ...

# %%
plt.boxplot(a["Annual Salary ($)"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a69c9c9310>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2a69c9e9350>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2a69c9afd90>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a69c9ea7d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a69c9c4ad0>],
#  'means': []}

# %%
b = df[(df["Department"])=="Sales"]
b
# Out:
#     Employee_Code   Gender Department  Annual Salary ($)  Age  Work_Experience
# 2             1012    Male      Sales              75000   31                7
# 3             1013    Male      Sales              61000   29                6
# 9             1019    Male      Sales              65000   32                7
# 10            1020    Male      Sales              54000   28                4
# 16            1026    Male      Sales              54000   28                5
# 20            1030    Male      Sales              94000   37               12
# 21            1031    Male      Sales              42000   27                5
# 32            1041    Male      Sales              36000   26                2
# 33            1042    Male      Sales              32000   24                1
# 34            1043  Female      Sales              30000   24                1
# 35            1044  Female      Sales              28500   23                1
# ...

# %%
plt.boxplot(b["Annual Salary ($)"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a69ca9f2d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2a69caa7190>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2a69ca9e910>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a69caa53d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a69caa5c90>],
#  'means': []}

# %%
c = df[(df["Department"])=="HR"]
c
# Out:
#     Employee_Code   Gender Department  Annual Salary ($)  Age  Work_Experience
# 6             1016  Female         HR              42000   27                4
# 14            1024  Female         HR              95000   35                9
# 17            1027  Female         HR              28000   22                0
# 18            1028    Male         HR              36000   25                3
# 28            1038  Female         HR              56000   29                5
# 29            1039  Female         HR             140000   49               20
# 30            1040    Male         HR              38000   26                3
# 37            1046  Female         HR              51000   28                4
# 41            1050  Female         HR              70000   35                9
# 43            1052  Female         HR              61000   31                7
# 49            1058  Female         HR              68500   34                9
# ...

# %%
plt.boxplot(c["Annual Salary ($)"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a69cb61dd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2a69cb63850>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2a69cb61410>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a69cb6c9d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a69c9bd410>],
#  'means': []}

# %%
d = df[(df["Department"])=="Finance"]
d
# Out:
#     Employee_Code   Gender Department  Annual Salary ($)  Age  Work_Experience
# 4             1014  Female    Finance              45000   27                4
# 5             1015    Male    Finance              40000   26                3
# 13            1023    Male    Finance              48000   27                4
# 22            1032  Female    Finance              30000   24                1
# 23            1033    Male    Finance              48000   27                4
# 31            1040    Male    Finance              68000   32                8
# 39            1048    Male    Finance              35000   26                2
# 40            1049    Male    Finance              65000   32                8
# 45            1054    Male    Finance              83000   36               10
# 51            1060    Male    Finance              80000   41               13
# 53            1062    Male    Finance              78000   40               12
# ...

# %%
plt.boxplot(d["Annual Salary ($)"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a69ca33b90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2a69c95a610>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2a69c9c5690>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a69c968150>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a69cb618d0>],
#  'means': []}

# %% [markdown]
# Interpretation - Here i have plotted boxplot for each department wise salary to find out if there are any outliers are present . IT and HR department has the outliers in their salary
