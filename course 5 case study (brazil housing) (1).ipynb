# %%
import pandas as pd
import numpy as np
import statistics as st
from tabulate import tabulate
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("DS1_C5_S3_BazilHousing_Data_Hackathon.csv")

# %%
df
# Out:
#                  city  area  rooms  bathroom  parking spaces  floor  \
# 0           São Paulo    70      2         1               1      7
# 1           São Paulo   320      4         4               0     20
# 2        Porto Alegre    80      1         1               1      6
# 3        Porto Alegre    51      2         1               0      2
# 4           São Paulo    25      1         1               0      1
# ...               ...   ...    ...       ...             ...    ...
# 10687    Porto Alegre    63      2         1               1      5
# 10688       São Paulo   285      4         4               4     17
# 10689  Rio de Janeiro    70      3         3               0      8
# 10690  Rio de Janeiro   120      2         2               2      8
# 10691       São Paulo    80      2         1               0      0
#
#           animal      furniture  hoa (R$)  rent amount (R$)  \
# 0          acept      furnished      2065              3300
# ...

# %% [markdown]
# ### performing basic (Level 0 ) operations
#
#
#  - Head() function is used to see the first four rows in the data
#  - Tail() function is used to see the last four rows in the data
#  - Shape() function is used to see how many rows and how many columns present in the data
#  - columns is used to identify the columns in the data
#  - info() is used to identify datatype of the columns
#  - isnull() is used to identify if there is any null values are present or not . if 'yes' then we have treat the null values according to their Data types . Whether its in Numeric or categorical .

# %%
df.head()
# Out:
#            city  area  rooms  bathroom  parking spaces  floor     animal  \
# 0     São Paulo    70      2         1               1      7      acept
# 1     São Paulo   320      4         4               0     20      acept
# 2  Porto Alegre    80      1         1               1      6      acept
# 3  Porto Alegre    51      2         1               0      2      acept
# 4     São Paulo    25      1         1               0      1  not acept
#
#        furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# 0      furnished      2065              3300                211
# 1  not furnished      1200              4960               1750
# 2  not furnished      1000              2800                  0
# 3  not furnished       270              1112                 22
# 4  not furnished         0               800                 25
#
#    fire insurance (R$)  total (R$)
# 0                   42        5618
# 1                   63        7973
# ...

# %%
df.shape
# Out:
# (10692, 13)

# %%
df.columns
# Out:
# Index(['city', 'area', 'rooms', 'bathroom', 'parking spaces', 'floor',
#        'animal', 'furniture', 'hoa (R$)', 'rent amount (R$)',
#        'property tax (R$)', 'fire insurance (R$)', 'total (R$)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10692 entries, 0 to 10691
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   city                 10692 non-null  object
#  1   area                 10692 non-null  int64
#  2   rooms                10692 non-null  int64
#  3   bathroom             10692 non-null  int64
#  4   parking spaces       10692 non-null  int64
#  5   floor                10692 non-null  int64
#  6   animal               10692 non-null  object
#  7   furniture            10692 non-null  object
#  8   hoa (R$)             10692 non-null  int64
#  9   rent amount (R$)     10692 non-null  int64
#  10  property tax (R$)    10692 non-null  int64
#  11  fire insurance (R$)  10692 non-null  int64
#  12  total (R$)           10692 non-null  int64
# dtypes: int64(10), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# #### checking for null values

# %%
df.isnull().sum()
# Out:
# city                   0
# area                   0
# rooms                  0
# bathroom               0
# parking spaces         0
# floor                  0
# animal                 0
# furniture              0
# hoa (R$)               0
# rent amount (R$)       0
# property tax (R$)      0
# fire insurance (R$)    0
# total (R$)             0
# dtype: int64

# %% [markdown]
# There  is no null values present in the data

# %% [markdown]
# #### Rename the columns name
#  - We can see that there are some value present in the () , its difficult to write the name and it will take time for analysis ,so by changing the name it will be very easy .

# %%
df = df.rename(columns={'parking spaces':'parking_spaces',
                  'hoa (R$)':'hoa',
                  'rent amount (R$)':'rent_amount',
                  'property tax (R$)':'property_tax',
                  'fire insurance (R$)':'fire_insurance',
                  'total (R$)':'total'})

# %%
df
# Out:
#                  city  area  rooms  bathroom  parking_spaces  floor  \
# 0           São Paulo    70      2         1               1      7
# 1           São Paulo   320      4         4               0     20
# 2        Porto Alegre    80      1         1               1      6
# 3        Porto Alegre    51      2         1               0      2
# 4           São Paulo    25      1         1               0      1
# ...               ...   ...    ...       ...             ...    ...
# 10687    Porto Alegre    63      2         1               1      5
# 10688       São Paulo   285      4         4               4     17
# 10689  Rio de Janeiro    70      3         3               0      8
# 10690  Rio de Janeiro   120      2         2               2      8
# 10691       São Paulo    80      2         1               0      0
#
#           animal      furniture   hoa  rent_amount  property_tax  \
# 0          acept      furnished  2065         3300           211
# ...

# %% [markdown]
# ###  Separating  numeric and categorical columns

# %%
# separating  numeric and categorical columns
numeric_columns = []
categorical_columns = []

for column in df.columns:
    if pd.api.types.is_numeric_dtype(df[column]):
        numeric_columns.append(column)
    else:
        categorical_columns.append(column)

print("Numeric Columns:", numeric_columns)
print("Categorical Columns:", categorical_columns)
# Out:
# Numeric Columns: ['area', 'rooms', 'bathroom', 'parking_spaces', 'floor', 'hoa', 'rent_amount', 'property_tax', 'fire_insurance', 'total']
# Categorical Columns: ['city', 'animal', 'furniture']

# %% [markdown]
# ### Univariant Analysis

# %% [markdown]
# ### Categorical columns

# %% [markdown]
# #### 1) City

# %%
def info_of_cat(col): 
    print(f"Unique values in {col} are: {df[col].unique()}") 
    print(f"Mode of {col} is {df[col].mode()[0]}") 
    print(f"Number of missing values in {col} is {df[col].isnull().sum()}")

# %%
info_of_cat("city")
# Out:
# Unique values in city are: ['São Paulo' 'Porto Alegre' 'Rio de Janeiro' 'Campinas' 'Belo Horizonte']
# Mode of city is São Paulo
# Number of missing values in city is 0

# %% [markdown]
# #### Visual presentation of city

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("count of cities")                  
percentage = df["city"].value_counts()         
labels = list(df["city"].value_counts().index) 
sns.countplot(x = df["city"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%") 
plt.show()

# %% [markdown]
# Interpretation - The chart indicates that the 55% of people lives in sao paulo , 14% in Rio de janeiro

# %% [markdown]
# #### 2) Animal

# %%
info_of_cat("animal")
# Out:
# Unique values in animal are: ['acept' 'not acept']
# Mode of animal is acept
# Number of missing values in animal is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Whether the animals are accepted or not")                  
percentage = df["animal"].value_counts()         
labels = list(df["animal"].value_counts().index) 

sns.countplot(x = df["animal"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%") 
plt.show()

# %% [markdown]
# Interpretation - animals are accepted in most of the cities

# %% [markdown]
# #### 3)  Furniture

# %%
info_of_cat("furniture")
# Out:
# Unique values in furniture are: ['furnished' 'not furnished']
# Mode of furniture is not furnished
# Number of missing values in furniture is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("The house are furnished or not")                  
percentage = df["furniture"].value_counts()         
labels = list(df["furniture"].value_counts().index) 

sns.countplot(x = df["furniture"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%") 
plt.show()

# %% [markdown]
# Interpretation - We can see that the number of non furnished house are higher than the house are furnished

# %% [markdown]
# ### Numerical columns

# %% [markdown]
# #### 1) Area

# %%
def info_of_numerical(col):
    print(f"The mean of the {col} is {df[col].mean()}")
    print(f"The median of the {col} is {df[col].median()}")
    print(f"The mode of the {col} is {df[col].mode()[0]}")
    print(f"The standard deviation of the {col} is {df[col].std()}")
    print(f"Number of missing values in the {col} is {df[col].isnull().sum()}")

# %%
info_of_numerical("area")
# Out:
# The mean of the area is 149.21791994014217
# The median of the area is 90.0
# The mode of the area is 50
# The standard deviation of the area is 537.0169423364867
# Number of missing values in the area is 0

# %% [markdown]
# Treating with outliers by using mean value ()

# %%
a = df["area"].mean()
a
# Out:
# 149.21791994014217

# %%
q = df[df["area"]>a].index
q
# Out:
# Int64Index([    1,     5,     7,     8,    15,    19,    22,    28,    34,
#                40,
#             ...
#             10669, 10670, 10673, 10675, 10680, 10681, 10682, 10683, 10686,
#             10688],
#            dtype='int64', length=3431)

# %%
for index in q :
    df.loc[q,"area"] = a

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               # Creating the space for the 2 images, first argument in subplots is rows and second is columns and the figure size
sns.histplot(x = df["area"], ax =ax[1], color = "b",bins=100) # ax[1] means image will plot at the second space
sns.boxplot(x = df["area"], ax = ax[0], color = "g") # ax[0] means image will plot at the second space
plt.show()

# %% [markdown]
# #### 2)Rooms

# %%
info_of_numerical("rooms")
# Out:
# The mean of the rooms is 2.506079311634867
# The median of the rooms is 2.0
# The mode of the rooms is 3
# The standard deviation of the rooms is 1.171266254098269
# Number of missing values in the rooms is 0

# %% [markdown]
# Treating with the outliers

# %%
s = df["rooms"].mean()
s
# Out:
# 2.506079311634867

# %%
w = df[df["rooms"]>s].index
w
# Out:
# Int64Index([    1,     5,     7,    15,    19,    20,    22,    24,    28,
#                34,
#             ...
#             10675, 10678, 10680, 10681, 10682, 10683, 10685, 10686, 10688,
#             10689],
#            dtype='int64', length=5263)

# %%
for index in w:
    df.loc[w,"rooms"] = s

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               
sns.histplot(x = df["rooms"], ax =ax[1], color = "black") 
sns.boxplot(x = df["rooms"], ax = ax[0], color = "grey") 
plt.show()

# %% [markdown]
# #### 3) Bathroom

# %%
info_of_numerical("bathroom")
# Out:
# The mean of the bathroom is 2.2368125701459034
# The median of the bathroom is 2.0
# The mode of the bathroom is 1
# The standard deviation of the bathroom is 1.4071981983604243
# Number of missing values in the bathroom is 0

# %% [markdown]
# Treating with the outliers

# %%
e = df["bathroom"].mean()
e
# Out:
# 2.2368125701459034

# %%
d = df[df["bathroom"]>e].index
d
# Out:
# Int64Index([    1,     5,     7,    15,    17,    19,    20,    34,    40,
#                44,
#             ...
#             10662, 10669, 10670, 10678, 10680, 10681, 10683, 10686, 10688,
#             10689],
#            dtype='int64', length=3481)

# %%
for index in d:
    df.loc[d,"bathroom"]=e

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               
sns.histplot(x = df["bathroom"], ax =ax[1], color = "grey") 
sns.boxplot(x = df["bathroom"], ax = ax[0], color = "black") 
plt.show()

# %% [markdown]
# #### 4) parking spaces

# %%
info_of_numerical("parking_spaces")
# Out:
# The mean of the parking_spaces is 1.6091470258136924
# The median of the parking_spaces is 1.0
# The mode of the parking_spaces is 1
# The standard deviation of the parking_spaces is 1.5895207238054723
# Number of missing values in the parking_spaces is 0

# %%
r = df["parking_spaces"].mean()
r
# Out:
# 1.6091470258136924

# %%
f = df[df["parking_spaces"]>r].index
f
# Out:
# Int64Index([    5,     7,    14,    15,    19,    22,    28,    30,    34,
#                35,
#             ...
#             10670, 10673, 10680, 10681, 10682, 10683, 10685, 10686, 10688,
#             10690],
#            dtype='int64', length=4379)

# %%
for index in f:
    df.loc[f,"parking spaces"]=r

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               
sns.histplot(x = df["parking spaces"], ax =ax[1], color = "grey") 
sns.boxplot(x = df["parking spaces"], ax = ax[0], color = "black") 
plt.show()

# %% [markdown]
# #### 5 )  floor

# %%
info_of_numerical("floor")
# Out:
# The mean of the floor is 5.0679947624392065
# The median of the floor is 3.0
# The mode of the floor is 0
# The standard deviation of the floor is 6.069050243218268
# Number of missing values in the floor is 0

# %%
t = df["floor"].mean()
t
# Out:
# 5.0679947624392065

# %%
g = df[df["floor"]>t].index
g
# Out:
# Int64Index([    0,     1,     2,     6,    11,    12,    14,    17,    18,
#                21,
#             ...
#             10672, 10673, 10675, 10677, 10679, 10685, 10686, 10688, 10689,
#             10690],
#            dtype='int64', length=3886)

# %%
for index in g:
    df.loc[g,"floor"] = t

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               
sns.histplot(x = df["floor"], ax =ax[1], color = "grey") 
sns.boxplot(x = df["floor"], ax = ax[0], color = "black") 
plt.show()

# %% [markdown]
# #### 6 ) House owner tax

# %%
info_of_numerical("hoa")
# Out:
# The mean of the hoa is 1174.0216984661429
# The median of the hoa is 560.0
# The mode of the hoa is 0
# The standard deviation of the hoa is 15592.305248403356
# Number of missing values in the hoa is 0

# %%
y = df["hoa"].mean()
y
# Out:
# 1174.0216984661429

# %%
h = df[df["hoa"]>y].index
h
# Out:
# Int64Index([    0,     1,     7,    17,    22,    32,    33,    34,    40,
#                44,
#             ...
#             10656, 10662, 10664, 10669, 10675, 10680, 10681, 10683, 10688,
#             10690],
#            dtype='int64', length=2839)

# %%
for index in h:
    df.loc[h,"hoa"] = y

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               
sns.histplot(x = df["hoa"], ax =ax[1], color = "red") 
sns.boxplot(x = df["hoa"], ax = ax[0], color = "black") 
plt.show()

# %% [markdown]
# #### 7 )  Rent amount (R$)

# %%
info_of_numerical("rent_amount")
# Out:
# The mean of the rent_amount is 3896.247194163861
# The median of the rent_amount is 2661.0
# The mode of the rent_amount is 2500
# The standard deviation of the rent_amount is 3408.5455176710816
# Number of missing values in the rent_amount is 0

# %%
m = df["rent_amount"].mean()
m
# Out:
# 3896.247194163861

# %%
i = df[df["rent_amount"]>m].index
i
# Out:
# Int64Index([    1,     5,     8,    13,    14,    15,    19,    34,    37,
#                40,
#             ...
#             10678, 10679, 10681, 10683, 10684, 10685, 10686, 10688, 10689,
#             10690],
#            dtype='int64', length=3632)

# %%
for index in i:
    df.loc[i,"rent_amount"]= m

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               
sns.histplot(x = df["rent_amount"], ax =ax[1], color = "grey",bins=10) 
sns.boxplot(x = df["rent_amount"], ax = ax[0], color = "black") 
plt.show()

# %% [markdown]
# #### 8 ) property tax (R$)

# %%
info_of_numerical("property_tax")
# Out:
# The mean of the property_tax is 366.70435839880287
# The median of the property_tax is 125.0
# The mode of the property_tax is 0
# The standard deviation of the property_tax is 3107.832321161917
# Number of missing values in the property_tax is 0

# %%
u = df["property_tax"].mean()
u
# Out:
# 366.70435839880287

# %%
j = df[df["property_tax"]>u].index
j
# Out:
# Int64Index([    1,     5,     7,    19,    33,    34,    37,    40,    44,
#                52,
#             ...
#             10661, 10662, 10664, 10669, 10675, 10678, 10680, 10681, 10683,
#             10688],
#            dtype='int64', length=2731)

# %%
for index in j:
    df.loc[j,"property_tax"] = u

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               
sns.histplot(x = df["property_tax"], ax =ax[1], color = "r",bins= 10) 
sns.boxplot(x = df["property_tax"], ax = ax[0], color = "black") 
plt.show()

# %% [markdown]
# #### 9) fire insurance (R$)

# %%
info_of_numerical("fire_insurance")
# Out:
# The mean of the fire_insurance is 53.300879161990274
# The median of the fire_insurance is 36.0
# The mode of the fire_insurance is 16
# The standard deviation of the fire_insurance is 47.768030930197206
# Number of missing values in the fire_insurance is 0

# %%
s = df["fire_insurance"].mean()
s
# Out:
# 53.300879161990274

# %%
p = df[df["fire_insurance"]>s].index
p
# Out:
# Int64Index([    1,     5,     8,    13,    14,    15,    19,    20,    37,
#                40,
#             ...
#             10662, 10664, 10669, 10678, 10681, 10685, 10686, 10688, 10689,
#             10690],
#            dtype='int64', length=3498)

# %%
for index in p:
    df.loc[p,"fire_insurance"] = s

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               
sns.histplot(x = df["fire_insurance"], ax =ax[1], color = "grey",bins=10) 
sns.boxplot(x = df["fire_insurance"], ax = ax[0], color = "black") 
plt.show()

# %% [markdown]
# #### 10 ) Total

# %%
info_of_numerical("total")
# Out:
# The mean of the total is 5490.4869996258885
# The median of the total is 3581.5
# The mode of the total is 2555
# The standard deviation of the total is 16484.72591235027
# Number of missing values in the total is 0

# %%
o = df["total"].mean()
o
# Out:
# 5490.4869996258885

# %%
k = df[df["total"]>o].index
k
# Out:
# Int64Index([    0,     1,     5,     7,     8,    15,    19,    33,    34,
#                37,
#             ...
#             10664, 10669, 10678, 10681, 10683, 10685, 10686, 10688, 10689,
#             10690],
#            dtype='int64', length=3403)

# %%
for index in k:
    df.loc[k,"total"]=o

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               
sns.histplot(x = df["total"], ax =ax[1], color = "grey",bins = 50) 
sns.boxplot(x = df["total"], ax = ax[0], color = "black") 
plt.show()

# %% [markdown]
# - Here i have analysed the Numerical columns with the Boxplot and Histogram
# - If there is any outliers present in the data . then Treated with the outliers

# %% [markdown]
# ### Bivariant Analysis -  To find the relationship between the tables

# %%
df.corr()
# Out:
# C:\Users\win 10\AppData\Local\Temp\ipykernel_24068\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                     area     rooms  bathroom  parking_spaces     floor  \
# area            1.000000  0.779059  0.780355        0.641518 -0.137838
# rooms           0.779059  1.000000  0.697702        0.500647 -0.075325
# bathroom        0.780355  0.697702  1.000000        0.578914 -0.025842
# parking_spaces  0.641518  0.500647  0.578914        1.000000 -0.141553
# floor          -0.137838 -0.075325 -0.025842       -0.141553  1.000000
# hoa             0.258325  0.227724  0.311223        0.097323  0.623812
# rent_amount     0.706192  0.487533  0.655865        0.556335  0.030975
# property_tax    0.696160  0.514482  0.621307        0.560676  0.015898
# ...

# %%
sns.heatmap(df.corr(),annot=True)

plt.rcParams["figure.figsize"] = (20,7)

plt.show()
# Out:
# C:\Users\win 10\AppData\Local\Temp\ipykernel_24068\1539646568.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# ### Bivariant analysis to find the relationship between  area and total

# %% [markdown]
# - Here the area column and city columns  .
# - If both the columns in numeric way while finding the relationship .In this situation we have to use sactter plot

# %% [markdown]
# ####  Relation of area and total

# %%
y = df["area"]
x = df["total"]
plt.scatter(x,y)
plt.show()

# %% [markdown]
# #### Relation of area and total
#
#  - Bi variant between the two numerical columns area and total , so i used scatter plot
#  - Here we can see that when the area is increasing ,we can see there is an increase in total .
#  - so we can say that the area and total are highly correlated

# %% [markdown]
# #### Relationship of rooms and total

# %%
y = df["rooms"]
x = df["total"]
plt.scatter(x,y)
plt.show()

# %% [markdown]
# #### Relationship of rooms and total
#
#  - We can see that , when the number of rooms are increasing , the total price is also increasing
#  - so we can say that the room is highly coorelated with the total .
#  - both are numeric columns , so i displayed the output using scatter plot

# %% [markdown]
# #### Relationship of parking spaces and total

# %%
y = df["parking_spaces"]
x = df["total"]
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ##### When the rent aount is increasing , we can see that the parking space is also increasing
# - Higher the amount pay for the rent , the parking space is also increased
# - hence we can say tht the Parking_spaces and rent are highly correlated

# %% [markdown]
# #### Realtionship between hoa and total

# %%
y = df["hoa"]
x = df["total"]
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ##### When the total amount is increasing , we can see that the HOA - House owner association Tax is also increasing
# - The price of hoa tax is detectable by the total amount rent pay by the person
# - hence we can say that the Hoa tax and total amount are highly correlated

# %% [markdown]
# #### Relationship between Fire insurance and rent amount

# %%
y = df["fire_insurance"]
x = df["rent_amount"]
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ##### By viewing the graph , we can easily say that the fire insurance and rent amount are highly correlated
# - The maximum of the rent aount will be go for the fire insurance
# - The fir insurance is very important for the house

# %% [markdown]
# #### Bi-variant Analysis for the city and rooms column

# %%
city_room = df.groupby(by=["city"])["rooms"].sum()
pd.DataFrame(city_room)
# Out:
#                        rooms
# city
# Belo Horizonte   2781.997194
# Campinas         1681.322297
# Porto Alegre     2211.901328
# Rio de Janeiro   2888.995604
# São Paulo       12029.278994

# %%
city_room.reset_index()
# Out:
#              city         rooms
# 0  Belo Horizonte   2781.997194
# 1        Campinas   1681.322297
# 2    Porto Alegre   2211.901328
# 3  Rio de Janeiro   2888.995604
# 4       São Paulo  12029.278994

# %%
plt.figure(figsize=(10, 6))
city_room.plot(kind='bar', color='skyblue')

plt.xlabel('City')
plt.ylabel('Number of Rooms')
plt.title('Number of Rooms in Different Cities')
plt.show()

# %% [markdown]
# ##### Relationship between city and rooms
# - Here we can clearly see that the sao paulo has the highest number of rooms

# %% [markdown]
# #### Relationship between city and Rent amount

# %%
df.groupby(['city'])['rent_amount'].aggregate(lambda x: x.sum()).plot(kind='bar' ,xlabel='City',ylabel='Total expense' ,
                                                                title='Total expense of houses in each city',figsize=(16,9),color=['cyan','gray','orange','pink','brown'])
# Out:
# <Axes: title={'center': 'Total expense of houses in each city'}, xlabel='City', ylabel='Total expense'>

# %% [markdown]
# ##### Here we can see that the sau paulo city has highest rent amount compared to others
# - The highest rent amount will only suitablr for the large families
# - The bachelors will not prefer the houses with rent amount are extremely high
# - Some of the Mid size families will afford to stay in sao paulo city

# %% [markdown]
# #### Relationship between city and HOA Tax

# %%
df.groupby(['city'])['hoa'].aggregate(lambda x: x.sum()).plot(kind='bar' ,xlabel='City',ylabel='House owner tax' ,
                                                                title='HOA Tax in each city',figsize=(16,9),color=['cyan','gray','orange','pink','brown'])
# Out:
# <Axes: title={'center': 'HOA Tax in each city'}, xlabel='City', ylabel='House owner tax'>

# %% [markdown]
# ###### Here also we can see that the sau paulo city has the highest Tax rate than others
# - Living in the city of sao paulo is Extremely high in paying the rent

# %% [markdown]
# ### Multi Variant Analysis - To find relationship between more than two columns

# %%
df
# Out:
#                  city       area     rooms  bathroom  parking_spaces  \
# 0           São Paulo   70.00000  2.000000  1.000000               1
# 1           São Paulo  149.21792  2.506079  2.236813               0
# 2        Porto Alegre   80.00000  1.000000  1.000000               1
# 3        Porto Alegre   51.00000  2.000000  1.000000               0
# 4           São Paulo   25.00000  1.000000  1.000000               0
# ...               ...        ...       ...       ...             ...
# 10687    Porto Alegre   63.00000  2.000000  1.000000               1
# 10688       São Paulo  149.21792  2.506079  2.236813               4
# 10689  Rio de Janeiro   70.00000  2.506079  2.236813               0
# 10690  Rio de Janeiro  120.00000  2.000000  2.000000               2
# 10691       São Paulo   80.00000  2.000000  1.000000               0
#
#           floor     animal      furniture          hoa  rent_amount  \
# 0      5.067995      acept      furnished  1174.021698  3300.000000
# ...

# %%
sns.barplot(x="total", y="furniture", hue="animal", data=df)
plt.show()

# %% [markdown]
# ##### We can see that the majrity of the apartments are furnished and they will accept animals

# %%
plt.figure(figsize=(16,9))
sns.barplot(x="rooms", y="city", hue="furniture", data=df)
plt.show()

# %% [markdown]
# ##### Sao paulo and Rio de jeneiro are the two cities , which has the highest rent amount compared to others
# - Sao paulo has the highest nmber of furnished houses than others and also non furnished houses

# %%
sns.scatterplot(x = "rent_amount", y="rooms" , hue="area" , data=df)
# Out:
# <Axes: xlabel='rent_amount', ylabel='rooms'>

# %% [markdown]
# ### Conclusion

# %% [markdown]
# ###### Large Families -   - Sao paulo and RIo de Jeneiro cities will be suitable for large families for living  because the cost of living is high
# - The max house are furnished and they allow pet animals
# - Large family need large space for living . These cities houses have number of rooms
# - So for the time of relocation , Sao paulo and Rio de Jeniro are suitable for large families
# - Every family couldn't afford that much prize , so also they can choose Porto Alegre for Livng .

# %% [markdown]
# ###### Mid size Families  - Porto Alegre and Campinas cities are suitable for mid size families
# - Mid size families will need upto 2 or 3 rooms , for that these cities are comfortable
# - They can also choose Sao paulo and Rio de Jeneiro

# %% [markdown]
# ######  Bachelors  - Belo Horizonto is the best place for living because the bachekors will prefer low cost of living
# - The Bachelors don't need plenty of rooms
# - they don't prefer large rent amount
# - That's why Belo Horizonto is suitable for Bachelors
