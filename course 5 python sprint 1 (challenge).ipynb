# %% [markdown]
# ### Task 1

# %%
import matplotlib.pyplot as plt             
from tabulate import tabulate               
import matplotlib as mat                     
import seaborn as sns                       
import pandas as pd                         
import numpy as np

# %%
df = pd.read_excel("DS1_C5_S1_Income_Data_Challenge.xlsx")

# %%
df
# Out:
#        Age   WorkClass    Education  Education_Num       Marital_Status  \
# 0       39   State-gov    Bachelors             13        Never-married
# 1       50    Self-emp    Bachelors             13   Married-civ-spouse
# 2       38     Private      HS-grad              9             Divorced
# 3       53     Private         11th              7   Married-civ-spouse
# 4       28     Private    Bachelors             13   Married-civ-spouse
# ...    ...         ...          ...            ...                  ...
# 32556   27     Private   Assoc-acdm             12   Married-civ-spouse
# 32557   40     Private      HS-grad              9   Married-civ-spouse
# 32558   58     Private      HS-grad              9              Widowed
# 32559   22     Private      HS-grad              9        Never-married
# 32560   52    Self-emp      HS-grad              9   Married-civ-spouse
#
#                Occupation    Relationship   Gender  Hours_Per_Week  \
# ...

# %%
df.shape
# Out:
# (32561, 11)

# %%
df.columns
# Out:
# Index(['Age', 'WorkClass', 'Education', 'Education_Num', 'Marital_Status',
#        'Occupation', 'Relationship', 'Gender', 'Hours_Per_Week',
#        'Native_Country', 'Income_Bracket'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Age               0
# WorkClass         0
# Education         0
# Education_Num     0
# Marital_Status    0
# Occupation        0
# Relationship      0
# Gender            0
# Hours_Per_Week    0
# Native_Country    0
# Income_Bracket    0
# dtype: int64

# %% [markdown]
# Interpretation - Here i have displayed the basic information about the dataset . shape of the dataset , column names and  the missing value

# %% [markdown]
# ### Task 2

# %%
# separating  numeric and categorical columns
numeric_columns = []
categorical_columns = []

for column in df.columns:
    if pd.api.types.is_numeric_dtype(df[column]):
        numeric_columns.append(column)
    else:
        categorical_columns.append(column)

table = [numeric_columns, categorical_columns]
print(tabulate({"numerical":numeric_columns,
                "categorical": categorical_columns}, headers = ["numerical", "categorical"]))
# Out:
# numerical       categorical
# --------------  --------------
# Age             WorkClass
# Education_Num   Education
# Hours_Per_Week  Marital_Status
#                 Occupation
#                 Relationship
#                 Gender
#                 Native_Country
#                 Income_Bracket

# %% [markdown]
# Interpretation - Here i have separated the numerical and categorical data according to thier types and displayed it in a table format

# %% [markdown]
# ### Task 3

# %%
def info_of_cat(col): 
    print(f"Unique values in {col} are: {df[col].unique()}") 
    print(f"Mode of {col} is {df[col].mode()[0]}") 
    print(f"Number of missing values in {col} is {df[col].isnull().sum()}")

# %%
info_of_cat("WorkClass")
# Out:
# Unique values in WorkClass are: [' State-gov' 'Self-emp' ' Private' ' Federal-gov' ' Local-gov' ' ?'
#  ' Self-emp' ' Without-pay' ' Never-worked']
# Mode of WorkClass is  Private
# Number of missing values in WorkClass is 0

# %%
info_of_cat("Education")
# Out:
# Unique values in Education are: [' Bachelors' ' HS-grad' ' 11th' ' Masters' ' 9th' ' Some-college'
#  ' Assoc-acdm' ' Assoc-voc' ' 7th-8th' ' Doctorate' ' Prof-school'
#  ' 5th-6th' ' 10th' ' 1st-4th' ' Preschool' ' 12th']
# Mode of Education is  HS-grad
# Number of missing values in Education is 0

# %%
info_of_cat("Marital_Status")
# Out:
# Unique values in Marital_Status are: [' Never-married' ' Married-civ-spouse' ' Divorced'
#  ' Married-spouse-absent' ' Separated' ' Married-AF-spouse' ' Widowed']
# Mode of Marital_Status is  Married-civ-spouse
# Number of missing values in Marital_Status is 0

# %%
info_of_cat("Occupation")
# Out:
# Unique values in Occupation are: [' Adm-clerical' ' Exec-managerial' ' Handlers-cleaners' ' Prof-specialty'
#  ' Other-service' ' Sales' ' Craft-repair' ' Transport-moving'
#  ' Farming-fishing' ' Machine-op-inspct' ' Tech-support' ' ?'
#  ' Protective-serv' ' Armed-Forces' ' Priv-house-serv']
# Mode of Occupation is  Prof-specialty
# Number of missing values in Occupation is 0

# %%
info_of_cat("Relationship")
# Out:
# Unique values in Relationship are: [' Not-in-family' ' Husband' ' Wife' ' Own-child' ' Unmarried'
#  ' Other-relative']
# Mode of Relationship is  Husband
# Number of missing values in Relationship is 0

# %%
info_of_cat("Gender")
# Out:
# Unique values in Gender are: [' Male' ' Female']
# Mode of Gender is  Male
# Number of missing values in Gender is 0

# %%
info_of_cat("Native_Country")
# Out:
# Unique values in Native_Country are: [' United-States' ' Cuba' ' Jamaica' ' India' ' ?' ' Mexico' ' South'
#  ' Puerto-Rico' ' Honduras' ' England' ' Canada' ' Germany' ' Iran'
#  ' Philippines' ' Italy' ' Poland' ' Columbia' ' Cambodia' ' Thailand'
#  ' Ecuador' ' Laos' ' Taiwan' ' Haiti' ' Portugal' ' Dominican-Republic'
#  ' El-Salvador' ' France' ' Guatemala' ' China' ' Japan' ' Yugoslavia'
#  ' Peru' ' Outlying-US(Guam-USVI-etc)' ' Scotland' ' Trinadad&Tobago'
#  ' Greece' ' Nicaragua' ' Vietnam' ' Hong' ' Ireland' ' Hungary'
#  ' Holand-Netherlands']
# Mode of Native_Country is  United-States
# Number of missing values in Native_Country is 0

# %%
info_of_cat("Income_Bracket")
# Out:
# Unique values in Income_Bracket are: [' <=50K' ' >50K']
# Mode of Income_Bracket is  <=50K
# Number of missing values in Income_Bracket is 0

# %% [markdown]
# Interpretation - In this task , i have performed the descriptive analysis of each categorical column and find out the unique values and the the mode of the column and check whether there is any missing value is present ,if it is then i replaced it with the mode value of the column

# %% [markdown]
# ### Task 4

# %%
# WorkClass

fig, ax = plt.subplots(1, 2, figsize = (20, 7))
ax[0].set_title("count of employes according to WorkClass")                 
percentage = df["WorkClass"].value_counts()        
labels = list(df["WorkClass"].value_counts().index)

sns.countplot(x = df["WorkClass"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %%
# Education

fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("count of employes according to Education")                 
percentage = df["Education"].value_counts()        
labels = list(df["Education"].value_counts().index)

sns.countplot(x = df["Education"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %%
# Marital_Status

fig, ax = plt.subplots(1, 2, figsize = (20, 7))
ax[0].set_title("count of employes according to Marital Status ")                 
percentage = df["Marital_Status"].value_counts()        
labels = list(df["Marital_Status"].value_counts().index)

sns.countplot(x = df["Marital_Status"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %%
#  Occupation

fig, ax = plt.subplots(1, 2, figsize = (20, 7))
ax[0].set_title("count of employes according to Occupation ")                 
percentage = df["Occupation"].value_counts()        
labels = list(df["Occupation"].value_counts().index)

sns.countplot(x = df["Occupation"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %%
# Relationship
                
fig, ax = plt.subplots(1, 2, figsize = (20, 7))
ax[0].set_title("count of employes according to their Relationship ")                 
percentage = df["Relationship"].value_counts()        
labels = list(df["Relationship"].value_counts().index)

sns.countplot(x = df["Relationship"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %%
 # Gender

fig, ax = plt.subplots(1, 2, figsize = (20, 7))
ax[0].set_title("count of employes according to their Gender ")                 
percentage = df["Gender"].value_counts()        
labels = list(df["Gender"].value_counts().index)

sns.countplot(x = df["Gender"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %%
# Native_Country

fig, ax = plt.subplots(1, 2, figsize = (20, 7))
ax[0].set_title("count of employes according to Native_Country")                 
percentage = df["Native_Country"].value_counts()        
labels = list(df["Native_Country"].value_counts().index)

sns.countplot(x = df["Native_Country"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %%
# Income_Bracket

fig, ax = plt.subplots(1, 2, figsize = (20, 7))
ax[0].set_title("count of employes according to Income_Bracket ")                 
percentage = df["Income_Bracket"].value_counts()        
labels = list(df["Income_Bracket"].value_counts().index)

sns.countplot(x = df["Income_Bracket"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# Interpretation - Here i have performed univariant analysis Bar chart and pie chart for the categorical column

# %% [markdown]
# ### Task 5

# %%
def info_of_numerical(col):
    print(f"The mean of the {col} is {df[col].mean()}")
    print(f"The median of the {col} is {df[col].median()}")
    print(f"The mode of the {col} is {df[col].mode()[0]}")
    print(f"The standard deviation of the {col} is {df[col].std()}")
    print(f"Number of missing values in the {col} is {df[col].isnull().sum()}")

# %%
info_of_numerical("Age")
# Out:
# The mean of the Age is 38.58164675532078
# The median of the Age is 37.0
# The mode of the Age is 36
# The standard deviation of the Age is 13.640432553581146
# Number of missing values in the Age is 0

# %%
info_of_numerical("Education_Num")
# Out:
# The mean of the Education_Num is 10.0806793403151
# The median of the Education_Num is 10.0
# The mode of the Education_Num is 9
# The standard deviation of the Education_Num is 2.5727203320673406
# Number of missing values in the Education_Num is 0

# %%
info_of_numerical("Hours_Per_Week")
# Out:
# The mean of the Hours_Per_Week is 40.437455852092995
# The median of the Hours_Per_Week is 40.0
# The mode of the Hours_Per_Week is 40
# The standard deviation of the Hours_Per_Week is 12.34742868173081
# Number of missing values in the Hours_Per_Week is 0

# %% [markdown]
# Interpretation - Here i have done a descriptive analysis on numerical columns and i have finded the Central tendancy , standard deviation , Missing values if there is any then have treat with the missing values

# %% [markdown]
# ### Task 6

# %%
#Age

fig, ax = plt.subplots(1, 2, figsize= (20, 7))               # Creating the space for the 2 images, first argument in subplots is rows and second is columns and the figure size
sns.histplot(x = df["Age"], ax =ax[1], color = "m") # ax[1] means image will plot at the second space
sns.boxplot(x = df["Age"], ax = ax[0], color = "g") # ax[0] means image will plot at the second space
plt.show()

# %%
# Education_Num

fig, ax = plt.subplots(1, 2, figsize= (20, 7))               # Creating the space for the 2 images, first argument in subplots is rows and second is columns and the figure size
sns.histplot(x = df["Education_Num"], ax =ax[1], color = "g") # ax[1] means image will plot at the second space
sns.boxplot(x = df["Education_Num"], ax = ax[0], color = "black") # ax[0] means image will plot at the second space
plt.show()

# %%
# Hours_per_week

fig, ax = plt.subplots(1, 2, figsize= (20, 7))               # Creating the space for the 2 images, first argument in subplots is rows and second is columns and the figure size
sns.histplot(x = df["Hours_Per_Week"], ax =ax[1], color = "m") # ax[1] means image will plot at the second space
sns.boxplot(x = df["Hours_Per_Week"], ax = ax[0], color = "g") # ax[0] means image will plot at the second space
plt.show()

# %% [markdown]
# Interpretation - Here i have done a discriptive analysis for the numerical columns and visualize the data by Box plot and Histogram
