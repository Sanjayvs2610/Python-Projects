# %% [markdown]
# ### Task 1 - identify the numbers of rows and columns in it and find any null values are present

# %%
import pandas as pd

# %%
data = pd.read_csv("DS1_C4_S3_Loan_Data_Challenge.csv")

# %%
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
data.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# Interpretation - There is no null value present in the data .

# %% [markdown]
# ### Task 2 - Display the list of female customers ,who are self-employeed and salary greater than 4000

# %%
gen = data[(data["Gender"]=="Female") & (data["Self_Employed"]=="Yes") & (data["ApplicantIncome"]>4000)]

# %%
gen
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 113  LP001392  Female      No          1      Graduate           Yes
# 353  LP002142  Female     Yes          0      Graduate           Yes
# 370  LP002194  Female      No          0      Graduate           Yes
# 404  LP002301  Female      No          0      Graduate           Yes
# 430  LP002377  Female      No          1      Graduate           Yes
# 439  LP002407  Female     Yes          0  Not Graduate           Yes
# 463  LP002489  Female      No          1  Not Graduate           Yes
# 493  LP002582  Female      No          0  Not Graduate           Yes
# 534  LP002731  Female      No          0  Not Graduate           Yes
# 561  LP002813  Female     Yes          1      Graduate           Yes
# 613  LP002990  Female      No          0      Graduate           Yes
#
# ...

# %% [markdown]
# Interpretation - Here i have displayed  the records ,list of female customers ,who are self-employeed and salary greater than 4000

# %% [markdown]
# ### Task 3 - Identify those male customers who hold gratuated degree and having loan status as 'Y' (yes)

# %%
male = data[(data["Gender"]=="Male") & (data["Education"]=="Graduate") & (data["Loan_Status"]=="Y")]

# %%
male
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 0    LP001002   Male      No          0  Graduate            No
# 2    LP001005   Male     Yes          0  Graduate           Yes
# 4    LP001008   Male      No          0  Graduate            No
# 5    LP001011   Male     Yes          2  Graduate           Yes
# 8    LP001018   Male     Yes          2  Graduate            No
# ..        ...    ...     ...        ...       ...           ...
# 606  LP002961   Male     Yes          1  Graduate            No
# 608  LP002974   Male     Yes          0  Graduate            No
# 610  LP002979   Male     Yes         3+  Graduate            No
# 611  LP002983   Male     Yes          1  Graduate            No
# 612  LP002984   Male     Yes          2  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         146               360
# ...

# %%
male.shape
# Out:
# (279, 13)

# %% [markdown]
# Interpretation - Here i have displayed those male customers who hold gratuated degree and having loan status as 'Y' (yes) and also the count of these customers is 279

# %% [markdown]
# ### Task 4

# %%
data[(data['Loan_Status']=="Y") & (data['Dependents'] >= "3") & (data['Property_Area']=="Rural")]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 126  LP001448    Male     Yes         3+      Graduate            No
# 213  LP001715    Male     Yes         3+  Not Graduate           Yes
# 255  LP001846  Female      No         3+      Graduate            No
# 324  LP002065    Male     Yes         3+      Graduate            No
# 352  LP002141    Male     Yes         3+      Graduate            No
# 376  LP002219    Male     Yes         3+      Graduate            No
# 390  LP002255    Male      No         3+      Graduate            No
# 391  LP002262    Male     Yes         3+      Graduate            No
# 481  LP002536    Male     Yes         3+  Not Graduate            No
# 515  LP002659    Male     Yes         3+      Graduate            No
# 522  LP002692    Male     Yes         3+      Graduate           Yes
# 539  LP002740    Male     Yes         3+      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
#
# ...

# %% [markdown]
# Interpretation - Here i have displayed the customer details whose loan status = Y , dependents = 3+ , Property_Area = rural and i didn't create any separate dataframe to display the details

# %% [markdown]
# ### Task 5

# %%
warner = data[(data["Gender"]=="Male") & (data["Education"]=="Graduate")  & (data["Property_Area"]=="Urban")]
warner
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 0    LP001002   Male      No          0  Graduate            No
# 2    LP001005   Male     Yes          0  Graduate           Yes
# 4    LP001008   Male      No          0  Graduate            No
# 5    LP001011   Male     Yes          2  Graduate           Yes
# 8    LP001018   Male     Yes          2  Graduate            No
# ..        ...    ...     ...        ...       ...           ...
# 594  LP002938   Male     Yes          0  Graduate           Yes
# 599  LP002948   Male     Yes          2  Graduate            No
# 602  LP002953   Male     Yes         3+  Graduate            No
# 611  LP002983   Male     Yes          1  Graduate            No
# 612  LP002984   Male     Yes          2  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         146               360
# ...

# %% [markdown]
# Interpretation - Warner kim will definetly get the loan .

# %% [markdown]
# ### Task 6

# %%
task_five = data[(data["Married"]=="No") & (data["Self_Employed"]=="Yes") & (data["Property_Area"]!="Urban")
                 & (data["Loan_Status"]=="N")]

# %%
task_five
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 32   LP001097    Male      No          1      Graduate           Yes
# 107  LP001370    Male      No          0  Not Graduate           Yes
# 286  LP001925  Female      No          0      Graduate           Yes
# 404  LP002301  Female      No          0      Graduate           Yes
# 410  LP002318  Female      No          1  Not Graduate           Yes
# 449  LP002444    Male      No          1  Not Graduate           Yes
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 32              4692                0.0         106               360
# 107             7333                0.0         120               360
# 286             2600             1717.0          99               300
# 404             7441                0.0         194               360
# ...

# %%
gender_grp = task_five.groupby(["Gender"])

# %%
gender_grp

# %%
for x,y in gender_grp:
    print(x)
    
    print(y)
# Out:
# Female
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 286  LP001925  Female      No          0      Graduate           Yes
# 404  LP002301  Female      No          0      Graduate           Yes
# 410  LP002318  Female      No          1  Not Graduate           Yes
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 286             2600             1717.0          99               300
# 404             7441                0.0         194               360
# 410             3867                0.0          62               360
# 613             4583                0.0         133               360
#
#      Credit_History Property_Area Loan_Status
# 286               1     Semiurban           N
# 404               1         Rural           N
# 410               1     Semiurban           N
# 613               0     Semiurban           N
# Male
# ...

# %% [markdown]
# Interpretation - There are totally 7 customers who satisfy the above conditions and there are 4 Female and 3 male.

# %% [markdown]
# ### Task  7

# %%
avg_income = data.groupby(by=["Property_Area"])["ApplicantIncome"].mean()

# %%
avg_income
# Out:
# Property_Area
# Rural        5554.083799
# Semiurban    5292.261803
# Urban        5398.247525
# Name: ApplicantIncome, dtype: float64

# %% [markdown]
# Interpretation - The above i have displayed the average income of the customers by property area

# %% [markdown]
# ### Task 8

# %%
task_eight = data[(data["Property_Area"]!="Urban") & (data["ApplicantIncome"]>4000) & (data["CoapplicantIncome"]>1000) 
                  & (data["Loan_Status"]=="N")]

# %%
task_eight
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 34   LP001100    Male      No         3+      Graduate            No
# 65   LP001225    Male     Yes          0      Graduate            No
# 83   LP001273    Male     Yes          0      Graduate            No
# 118  LP001421    Male     Yes          0      Graduate            No
# 129  LP001465    Male     Yes          0      Graduate            No
# 139  LP001493    Male     Yes          2  Not Graduate            No
# 140  LP001497    Male     Yes          2      Graduate            No
# 148  LP001519  Female      No          0      Graduate            No
# 177  LP001610    Male     Yes         3+      Graduate            No
# 258  LP001859    Male     Yes          0      Graduate            No
# 298  LP001955  Female      No          0      Graduate            No
# ...

# %%
task_eight['Loan_Status']= task_eight['Loan_Status'].str.replace("N", "Y")
# Out:
# C:\Users\win 10\AppData\Local\Temp\ipykernel_18832\392957923.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   task_eight['Loan_Status']= task_eight['Loan_Status'].str.replace("N", "Y")

# %%
task_eight
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 34   LP001100    Male      No         3+      Graduate            No
# 65   LP001225    Male     Yes          0      Graduate            No
# 83   LP001273    Male     Yes          0      Graduate            No
# 118  LP001421    Male     Yes          0      Graduate            No
# 129  LP001465    Male     Yes          0      Graduate            No
# 139  LP001493    Male     Yes          2  Not Graduate            No
# 140  LP001497    Male     Yes          2      Graduate            No
# 148  LP001519  Female      No          0      Graduate            No
# 177  LP001610    Male     Yes         3+      Graduate            No
# 258  LP001859    Male     Yes          0      Graduate            No
# 298  LP001955  Female      No          0      Graduate            No
# ...

# %% [markdown]
# Interpretation - here i have updated the loan status from "N" to "Y"of customers who satisfy the above filters

# %% [markdown]
# ### Task 9

# %%
avg_count = data[(data["Dependents"]=="3+") & (data["Property_Area"]=="Urban") & (data["Loan_Status"]=="Y")]

# %%
avg_count
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 61   LP001206   Male     Yes         3+      Graduate            No
# 68   LP001238   Male     Yes         3+  Not Graduate           Yes
# 171  LP001585   Male     Yes         3+      Graduate            No
# 267  LP001882   Male     Yes         3+      Graduate            No
# 295  LP001949   Male     Yes         3+      Graduate            No
# 461  LP002484   Male     Yes         3+      Graduate            No
# 531  LP002720   Male     Yes         3+      Graduate            No
# 602  LP002953   Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 61              3029                0.0          99               360
# 68              7100                0.0         125                60
# 171            51763                0.0         700               300
# 267             4333             1811.0         160               360
# ...

# %%
avg = avg_count["ApplicantIncome"].mean()

# %%
avg
# Out:
# 11045.625

# %%
avg_count.shape
# Out:
# (8, 13)

# %% [markdown]
# Interpretation - There are totally 8 customer who satisfy the above conditions and the average income of those customers is 11045.625

# %% [markdown]
# ### Task 10

# %%
area = data[data["Property_Area"]=="Urban"]
area
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 600  LP002949  Female      No         3+      Graduate           Yes
# 602  LP002953    Male     Yes         3+      Graduate            No
# 605  LP002960    Male     Yes          0  Not Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
ar = area["ApplicantIncome"].mean()
ar
# Out:
# 5398.247524752475

# %%
s = data[(data["Property_Area"]!="Urban") & (data["Dependents"]=="3+") & (data["ApplicantIncome"]>5398.247)]

# %%
s
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 34   LP001100   Male      No         3+      Graduate            No
# 126  LP001448   Male     Yes         3+      Graduate            No
# 155  LP001536   Male     Yes         3+      Graduate            No
# 177  LP001610   Male     Yes         3+      Graduate            No
# 213  LP001715   Male     Yes         3+  Not Graduate           Yes
# 324  LP002065   Male     Yes         3+      Graduate            No
# 376  LP002219   Male     Yes         3+      Graduate            No
# 390  LP002255   Male      No         3+      Graduate            No
# 391  LP002262   Male     Yes         3+      Graduate            No
# 409  LP002317   Male     Yes         3+      Graduate            No
# 522  LP002692   Male     Yes         3+      Graduate           Yes
# 539  LP002740   Male     Yes         3+      Graduate            No
# 557  LP002795   Male     Yes         3+      Graduate           Yes
# ...

# %% [markdown]
# 1) I have infered something from the above task that the bank gave loan for the customers who have greater than 3+ Dependents

# %%
A = s["ApplicantIncome"].mean()

# %%
A
# Out:
# 16595.866666666665

# %% [markdown]
# 2)These are the average applicantincome of the customers who are from non-Urban area
