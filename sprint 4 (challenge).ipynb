# %% [markdown]
# ## MCQ QIUZ

# %%
Q = {
    "1) Number of Continents on Earth": "1:Seven 2:Four 3:Five 4:Six",
    "2) Which country successfully landed a man on the moon": "1:USA 2:Germany 3:France 4:England",
    "3) Which country is not present in the continent of North America": "1:Mexico 2:USA 3:Canada 4:Brazil",
    "4) Which is the American National Bird": "1:Parrot 2:Crane 3:Eagle 4:Swan",
    "5) Which country shares the longest border with the USA": "1:Mexico 2:Brazil 3:Canada 4:Argentina",
    "6) Which is the financial capital of the USA": "1:San Francisco 2:Boston 3:Los Angeles 4:NYC",
    "7) Which of the following space agencies belongs to the USA": "1:BNSC 2:ISRO 3:DLR 4:NASA",
    "8) Which is the second most spoken language in the USA": "1:English 2:Spanish 3:Mandarin 4:Italian",
    "9) Which is the capital city of the USA": "1:NYC 2:Washington DC 3:Austin 4:San Jose",
    "10) Mt Rushmore has the sculpture of": "1:Former US Presidents 2:Hollywood stars 3:Military Personnel 4:Scientists"
}

A = list(Q.values())
CA = [1, 1, 4, 3, 3, 4, 4, 2, 2, 1]  # List of correct options
myit = iter(A)
score = 0
incorrect = 0
for i in Q:
    print(i)
    a = next(myit)
    print(a)
    print("\n")
    ans = int(input("Enter the option between 1 and 4:"))
    
    if ans == CA[list(Q.keys()).index(i)]:
        score+=2
        print("Correct!")
        print("\n")
    else:
        print("Incorrect!")
        incorrect+=1
        print("\n")

print("Final score is:", score,"out of 20")
print("The number of question incorrect is : ",incorrect)
# Out:
# 1) Number of Continents on Earth
# 1:Seven 2:Four 3:Five 4:Six
#
#
# Enter the option between 1 and 4:1
# Correct!
#
#
# 2) Which country successfully landed a man on the moon
# 1:USA 2:Germany 3:France 4:England
#
#
# Enter the option between 1 and 4:1
# Correct!
#
#
# 3) Which country is not present in the continent of North America
# 1:Mexico 2:USA 3:Canada 4:Brazil
#
#
# Enter the option between 1 and 4:4
# Correct!
#
#
# 4) Which is the American National Bird
# 1:Parrot 2:Crane 3:Eagle 4:Swan
#
#
# Enter the option between 1 and 4:2
# Incorrect!
#
#
# 5) Which country shares the longest border with the USA
# 1:Mexico 2:Brazil 3:Canada 4:Argentina
#
#
# Enter the option between 1 and 4:3
# Correct!
#
#
# 6) Which is the financial capital of the USA
# 1:San Francisco 2:Boston 3:Los Angeles 4:NYC
#
#
# Enter the option between 1 and 4:1
# Incorrect!
#
#
# 7) Which of the following space agencies belongs to the USA
# 1:BNSC 2:ISRO 3:DLR 4:NASA
#
#
# ...
